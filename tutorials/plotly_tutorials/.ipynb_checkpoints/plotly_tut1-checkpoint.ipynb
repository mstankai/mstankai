# %% [markdown]
# # Plotly Practice
#
# This notebook follows the data visualization tutorial for `seaborn` from Kaggle, but I will used `plotly` to produce said plots.

# %%
# general
import numpy as np
import pandas as pd
pd.plotting.register_matplotlib_converters()

# mpl
import matplotlib as mpl
import matplotlib.pyplot as plt

# plotly
import plotly.express as px
import plotly.io as pio
pio.renderers.default = 'iframe'

# stats
from scipy import stats

# %%
# import data
candy_path = '../data/datavis/candy.csv'
candy = pd.read_csv(candy_path,index_col='id')

# %%
# view data
candy.head()
# Out:
#    competitorname chocolate fruity caramel peanutyalmondy nougat  \
# id
# 0       100 Grand       Yes     No     Yes             No     No
# 1    3 Musketeers       Yes     No      No             No    Yes
# 2       Air Heads        No    Yes      No             No     No
# 3      Almond Joy       Yes     No      No            Yes     No
# 4       Baby Ruth       Yes     No     Yes            Yes    Yes
#
#    crispedricewafer hard  bar pluribus  sugarpercent  pricepercent  winpercent
# id
# 0               Yes   No  Yes       No         0.732         0.860   66.971725
# 1                No   No  Yes       No         0.604         0.511   67.602936
# 2                No   No   No       No         0.906         0.511   52.341465
# 3                No   No  Yes       No         0.465         0.767   50.347546
# 4                No   No  Yes       No         0.604         0.767   56.914547

# %%
# plotting a scatterplot of sugar vs popularity

# labels
f_title = "Sugar content vs. Popularity"
ax_labels = { 'x' : "Sugar content (%)"
             ,'y' : "Popularity (%)"
            }

# make figure
fig = px.scatter(x=candy.sugarpercent*100
                ,y=candy.winpercent
                ,title=f_title
                ,labels=ax_labels
                )
# centre title
fig.update_layout(title_x=0.5, title_y=.85)

# plot
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_4.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
# plot popularity vs sugar content with regression

# labels
f_title = "Sugar content vs. Popularity"
ax_labels = { 'x' : "Sugar content (%)"
             ,'y' : "Popularity (%)"
            }

# make figure
fig = px.scatter(x=candy.sugarpercent
                ,y=candy.winpercent
                ,title=f_title
                ,labels=ax_labels
                ,trendline='ols')

# centre title
fig.update_layout(title_x=0.5, title_y=.85)

# plot
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_5.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
# print result information
fit_res = px.get_trendline_results(fig)
fit_res.query("0").px_fit_results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.043
# Model:                            OLS   Adj. R-squared:                  0.031
# Method:                 Least Squares   F-statistic:                     3.649
# Date:                Wed, 22 Jun 2022   Prob (F-statistic):             0.0596
# Time:                        13:11:46   Log-Likelihood:                -338.81
# No. Observations:                  83   AIC:                             681.6
# Df Residuals:                      81   BIC:                             686.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         45.1588      3.257     13.866      0.000      38.679      51.639
# x1            11.0756      5.798      1.910      0.060      -0.460      22.611
# ==============================================================================
# Omnibus:                        2.998   Durbin-Watson:                   1.696
# Prob(Omnibus):                  0.223   Jarque-Bera (JB):                2.724
# Skew:                           0.358   Prob(JB):                        0.256
# Kurtosis:                       2.475   Cond. No.                         4.57
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# plot popularity vs price with regression
# categorised by --> chocolate content

# labels
f_title = "Price vs. Popularity"
ax_labels = { 'pricepercent' : "Price Distribution (%)"
             ,'winpercent'   : "Popularity (%)"
            }

# make figure
fig = px.scatter(candy
                ,x='pricepercent'
                ,y='winpercent'
                ,color='chocolate'
                ,title=f_title
                ,labels=ax_labels
                ,trendline='ols'
                ,width=600
                ,height=400)


# plot
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="620px"
#     height="420"
#     src="iframe_figures/figure_7.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>
